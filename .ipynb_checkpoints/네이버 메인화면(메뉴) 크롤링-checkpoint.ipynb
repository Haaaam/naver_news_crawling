# %% [markdown]
# ### 크롤링
# - 웹 크롤러(web crawling)에서 출발한 말로 크롤러는 무수히 많은 인터넷 상의 페이지(문서, html 등)을 수집해서 분류하고 저장한 후 나중에 쉽게 찾아볼 수 있도록 하는 역할을 하는 일종의 로봇이다.
# - 크롤링은 웹 상의 문서를 수집해주는 작업니다.
# ### 파싱(Parsing)
# - 어떤 페이지(문서, html 등)에서 원하는 데이터를 특정 패턴이나 순서로 추출하여 정보로 가공하는 것을 말한다.
# ### 스크래핑(scrapping)
# - 데이터를 수집하는 모든 작업을 말한다.

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url='https://www.naver.com'
html=requests.get(url)
soup=bs(html.content,'html.parser')

# %%
#soup
htxt=soup.find('div',{'class':'group_nav'})
htxt
# Out:
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.shopping" href="https://shopping.naver.com/">쇼핑</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul class="list_nav NM_FAVORITE_LIST">
# ...

# %%
s=htxt.find_all('li')
for i in s:
    print(i.text)
# Out:
# 메일
#
# 카페
# 블로그
# 지식iN
# 쇼핑
# Pay
#
# TV
#
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# 영화
# VIBE
# 책
# 웹툰
#
# 책
# 웹툰

# %%
import requests
from bs4 import BeautifulSoup as bs
url='https://www.naver.com/'
html=requests.get(url)
soup=bs(html.content, 'html.parser')
htxt=soup.find('div',{'class':"group_nav"})
htxt
# 네이버 그룹메뉴 전체

li_tmps=htxt.find_all('li')
for li in li_tmps:
    print(li.text)
# 네이버 그룹메뉴_일부
ul_tmps=htxt.find('ul', {'class':'list_nav NM_FAVORITE_LIST'})
li_tmps=ul_tmps.find_all('li')
for li in li_tmps:
    print(li.text)
# Out:
# 메일
#
# 카페
# 블로그
# 지식iN
# 쇼핑
# Pay
#
# TV
#
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# 영화
# VIBE
# 책
# 웹툰
#
# 책
# 웹툰
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# 영화
# VIBE
# 책
# 웹툰
#
# 책
# 웹툰

# %% [markdown]
# ### 네이버

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url='https://www.naver.com/'
html=requests.get(url)
soup=bs(html.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
ul_tmp=soup.find('ul',{'class':'list_theme'})
ul_tmp
# Out:
# <ul class="list_theme">
# <li class="theme_item">
# <a class="theme_thumb" data-clk="tcc_scl.editsmallimg1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30250067&amp;memberNo=34921815" target="_blank">
# <img alt="온라인 수업에서 정말 중요한 '읽고 메모하기'" data-src="https://s.pstatic.net/static/www/mobile/edit/2021/0107/cropImg_196x196_51920945371074805.jpeg" height="98" src="https://s.pstatic.net/static/www/mobile/edit/2021/0107/cropImg_196x196_51920945371074805.jpeg" width="98"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_scl.editsmalltxt1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30250067&amp;memberNo=34921815" target="_blank">
# <em class="theme_category">오늘의 Pick</em>
# <strong class="title">온라인 수업에서 정말 중요한 '읽고 메모하기' </strong>
# <div class="source_box">
# <span class="source"><span class="source_inner">스쿨잼</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item">
# ...

# %%
a_tmps=ul_tmp.find_all('a',{'class':'theme_info'})
a_tmps
# Out:
# [<a class="theme_info" data-clk="tcc_scl.editsmalltxt1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30250067&amp;memberNo=34921815" target="_blank">
#  <em class="theme_category">오늘의 Pick</em>
#  <strong class="title">온라인 수업에서 정말 중요한 '읽고 메모하기' </strong>
#  <div class="source_box">
#  <span class="source"><span class="source_inner">스쿨잼</span></span>
#  </div>
#  </a>,
#  <a class="theme_info" data-clk="tcc_scl.editsmalltxt2" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30107160&amp;memberNo=33296067" target="_blank">
#  <em class="theme_category">보고 읽고 느껴봐요</em>
#  <strong class="title">5~6학년을 위한 올겨울 추천도서 5 </strong>
#  <div class="source_box">
#  <span class="source"><span class="source_inner">비상교육</span></span>
#  </div>
#  </a>,
#  <a class="theme_info" data-clk="tcc_scl.editsmalltxt3" href="https://blog.naver.com/elihigh/222174695658" target="_blank">
#  <em class="theme_category">과학 탐구 생활</em>
#  <strong class="title">찰칵! '간이 사진기' 만들기에 도전! </strong>
# ...

# %%
a_tmps[0]
# Out:
# <a class="theme_info" data-clk="tcc_scl.editsmalltxt1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30250067&amp;memberNo=34921815" target="_blank">
# <em class="theme_category">오늘의 Pick</em>
# <strong class="title">온라인 수업에서 정말 중요한 '읽고 메모하기' </strong>
# <div class="source_box">
# <span class="source"><span class="source_inner">스쿨잼</span></span>
# </div>
# </a>

# %%
print(a_tmps[0].find('em').text)

print(a_tmps[0].find('strong').text)

print(a_tmps[0].find('span').text)
# Out:
# 오늘의 Pick
# 온라인 수업에서 정말 중요한 '읽고 메모하기'
# 스쿨잼

# %%
# !pip install pandas

# %%
#데이터 전체 출력
import pandas as pd
data=[]
for i in a_tmps:
    gro=i.find('em').text
    tit=i.find('strong').text
    date=i.find('span').text
    by=at.find('p').text
    data.append([gro,tit,by,date])
data
df1=pd.DataFrame(data, columns=['그룹','제목','내용','기간'])
df1
# Out:
#      그룹                                  제목  \
# 0  인사관리     위대한 아이디어를 원한다면 팀원의 '일탈'을 허용해라?
# 1  조직관리  "조직문화는 필요 없고 매출만 나오면 된다"는 상사 설득하기
# 2  해볼깝쇼  90년대 생 인턴 vs 70년대 생 팀장, 레트로 전격 비교
#
#                                                   내용        기간
# 0  ​​​판매량으로 본 중국의 유명한 담배브랜드 Top105위에서 1위​​어제 올린 '...  동아비즈니스리뷰
# 1  ​​​판매량으로 본 중국의 유명한 담배브랜드 Top105위에서 1위​​어제 올린 '...   HR 인사이트
# 2  ​​​판매량으로 본 중국의 유명한 담배브랜드 Top105위에서 1위​​어제 올린 '...      인터비즈

# %%
import requests
from bs4 import BeautifulSoup as bs
url='https://www.naver.com/'
html=requests.get(url)
soup=bs(html.content, 'html.parser')
ul_tmp=soup.find('ul', {'class':'list_theme'})
# ul_tmp
a_tmps=ul_tmp.findAll('a',{'class':'theme_info'})
#a_tmps
a_tmps[0]
print(a_tmps[0].find('em').text)
print(a_tmps[0].find('strong').text)
print(a_tmps[0].find('p').text)
print(a_tmps[0].find('span').text)
import pandas as pd
# 데이터 전체
data=[]

for at in a_tmps:
    gro=at.find('em').text
    tit=at.find('strong').text
    by=at.find('p').text
    date=at.find('span').text
    data.append([gro, tit, by, date])
    
data
df1=pd.DataFrame(data, columns=['그룹','제목','내용','기간'])
df1
# Out:
# 클래식 이야기
# 슈만, 쇼팽이 쓴 '헌정곡'에 숨은 의미는?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-d21ed413e09f> in <module>
#      11 print(a_tmps[0].find('em').text)
#      12 print(a_tmps[0].find('strong').text)
# ---> 13 print(a_tmps[0].find('p').text)
#      14 print(a_tmps[0].find('span').text)
#      15 import pandas as pd
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ### [미션] 네이버 주제별 크롤 (10개)

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
url='https://www.naver.com/'
html=requests.get(url)
soup=bs(html.content, 'html.parser')
ul_tmps=soup.find_all('ul', {'class':'list_theme'})

for i in range(1, 3):
    a_tmps=ul_tmps[i].find_all('a', {'class':'theme_info'})
    for at in a_tmps:
        gro=at.find('em').text
        tit=at.find('strong').text
        by=at.find('p').text
        date=at.find('span').text
        data.append([gro, tit, by, date])
    
df1=pd.DataFrame(data, columns=['그룹','제목','내용','기간'])
df1
# Out:
#      그룹                            제목  \
# 0   스쿨잼      사춘기 아들이 담배를 끊게 만든 아버지의 말
# 1   스쿨잼           내 몸의 수분 부족 알리는 신호 5
# 2   스쿨잼   부처님은 머리가 있는데 스님은 왜 모두 대머리일까
# 3   스쿨잼       층간소음 걱정없이 집에서 살 빼는 동작 5
# 4   스쿨잼  한국인은 2020년 프라이드치킨을 얼마나 먹었을까?
# 5   스쿨잼               찹쌀호떡믹스 망한 후기 ㅎㅎ
# 6   스쿨잼       손수 만든 핸드메이드 6공 다이어리 제작기
# 7   스쿨잼                세계 곳곳의 이색 직업 5
#
#                                                   내용     기간
# 0  철없던 고등학교 시절, 이리저리 방황하며 담배를 입에 댔던 A씨는 아버지의 한 마디...  1주일 전
# 1  [사진=fizkes/gettyimagesbank] 목이 마르다는 건 체내 수분이 부...  1주일 전
# 2  어떤 절대적인 위치에 있는 존재를 믿거나 숭배하고그들의 사상을 따르며 삶의 의미를 ...  1주일 전
# 3  프로그 크런치프로그 크런치는 복부 지방에 효과적인 동작으로 상체를 많이 숙이는 것보...   6일 전
# 4  무려 7조 3천억 원어치 최근 보도에 따르면, 2020년 한 해 동안 한국인이 먹은...  1주일 전
# 5  겨울철 나의 최애 간식은 호떡이다근데 슬프게도 요새 호떡 파는 곳이 잘 없다붕어빵만...  3주일 전
# 6  안녕하세요~ 덕질남녀입니다.저는 해마다 12월은 다이어리를 선택하느라 고민의 늪에 ...  1주일 전
# 7  우리가 흔히 알고 있는 교사, 건축가, 게임 개발자, 항공종사자, 프로듀서 등 직업...  1주일 전
